# %%
import matplotlib.pyplot as plt
import random
# Data
countries = ['World', 'Denmark', 'Taiwan', 'Turkey']
eCapitas = [3.66, 5.69, 11.18, 3.73]
eTotals = [29.6, 0.038, 0.274, 0.0325]
barLength = [1, 1, 1, 1]
elMixes = {
    'World': [0.36, 0.22, 0.14, 0.09, 0.06,0.08,0.03,0.02,0],
    'Denmark': [0.08, 0.03, 0, 0, 0.09, 0.58, 0.02, 0.21, 0 ],
    'Taiwan': [0.43, 0.4, 0.01, 0.07, 0.05, 0.02, 0.01, 0.01, 0],
    'Turkey': [0.37, 0.21, 0.2, 0, 0.06, 0.11, 0, 0.03, 0.03]
}
labels = ['coal', 'gas', 'hydro', 'nuclear', 'PV', 'wind', 'oil', 'bio', 'other'] 
#colors = ["#%06x" % random.randint(0x111111, 0xFFFFFF) for _ in labels]
colors = ['#b6407d', '#438dc9', '#3c1e69', '#ccf108', '#b566f2', '#ADD8E6', '#30d3e2', '#8375b6', '#81aed9']

countries_with_values = [f"{country}\n{value:.2f} MWh/capita \n{eTotal:.2f} TWh/year" for country, value, eTotal in zip(countries, eCapitas, eTotals)]

# Create horizontal bar chart
plt.figure(figsize=(10, 6))

for i, (country, value) in enumerate(zip(countries_with_values, barLength)):
    start = 0
    for j, (mix, color) in enumerate(zip(elMixes[countries[i]], colors)):
        bar_width = value * mix
        bars = plt.barh(country, bar_width, left=start, color=color)

        if bar_width >= 0.02:
            plt.text(start + bar_width / 2, i, f'{mix * 100:.0f}%', va='center', ha='center', color='white', fontsize=12,fontweight='bold')
        start += bar_width

# Add labels and title
plt.xlabel('The shares which larger than 2% are displayed')
plt.title('Electricity Mix 2023',fontsize=16, fontweight='bold')
plt.yticks(fontsize=12,fontweight='bold')

# Format x-axis with scientific notation for clarity
plt.ticklabel_format(axis='x', style='sci', scilimits=(0, 0))

# Add legend
legend = plt.legend(labels,framealpha=0,loc='upper center',bbox_to_anchor=(0.5, -0.1), ncol=len(labels),fontsize=12)
for text in legend.get_texts():
    text.set_fontweight('bold')
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import random
# Data
countries = ['World', 'Denmark', 'Taiwan', 'Turkey']
#eCapita = [7.33e3, 1.14e4, 2.35e4, 7.45e3]
eCapitas = [7.33, 11.14, 2.35, 7.45]
#eTotals = [7.18e13, 7.17e10, 4.80e11, 6.97e11]
eTotals = [71.8, 0.0717, 0.480, 0.697]
barLength = [1, 1, 1, 1]
elMixes = {
    'World': [0.1, 0.23, 0.15, 0.09, 0.06,0.37,0,0,0],
    'Denmark': [0.0011, 0.002, 0, 0, 0.1, 0.86, 0.0004, 0.091, 0 ],
    'Taiwan': [0.15, 0.14, 0.12, 0, 0.24, 0.33, 0.001, 0.01, 0],
    'Turkey': [0.23, 0.15, 0.24, 0.08, 0.09, 0.15, 0, 0.03, 0.04]
}
labels = ['coal', 'gas', 'hydro', 'nuclear', 'PV', 'wind', 'oil', 'bio', 'other'] 
#colors = ["#%06x" % random.randint(0x111111, 0xFFFFFF) for _ in labels]
#print(colors)
colors = ['#b6407d', '#438dc9', '#3c1e69', '#ccf108', '#b566f2', '#ADD8E6', '#30d3e2', '#8375b6', '#81aed9']
countries_with_values = [f"{country}\n{value:.2f} MWh/capita \n{eTotal:.2f} TWh/year" for country, value, eTotal in zip(countries, eCapitas, eTotals)]

# Create horizontal bar chart
plt.figure(figsize=(10, 6))

for i, (country, value) in enumerate(zip(countries_with_values, barLength)):
    start = 0
    for j, (mix, color) in enumerate(zip(elMixes[countries[i]], colors)):
        bar_width = value * mix
        bars = plt.barh(country, bar_width, left=start, color=color)

        if bar_width >= 0.02:
            plt.text(start + bar_width / 2, i, f'{mix * 100:.0f}%', va='center', ha='center', color='white', fontsize=12,fontweight='bold')
        start += bar_width

# Add labels and title
plt.xlabel('The shares which larger than 2% are displayed')
plt.title('Electricity Mix 2050',fontsize=16, fontweight='bold')
plt.yticks(fontsize=12,fontweight='bold')

# Format x-axis with scientific notation for clarity
plt.ticklabel_format(axis='x', style='sci', scilimits=(0, 0))

# Add legend
legend = plt.legend(labels,framealpha=0,loc='upper center',bbox_to_anchor=(0.5, -0.1), ncol=len(labels),fontsize=12)
for text in legend.get_texts():
    text.set_fontweight('bold')

# Show the plot
plt.show()
